# %%
import requests
import json
import pandas as pd
from config import geoapify_key
import time
import re

#Show all 100 rows
pd.set_option('display.max_rows', 100)

# %%
# Read the cleaned data
df = pd.read_csv('../data/nhomes_cleaned.csv', delimiter=',')

# %%
# Set the timeout between the attempts
timeout = 10

# Limit the number of attempts
maxAttempt = 10

def getLocations(locations):
    url = "https://api.geoapify.com/v1/batch/geocode/search?apiKey=" + geoapify_key
    response = requests.post(url, json = locations)
    result = response.json()
    
    # The API returns the status code 202 to indicate that the job was accepted and pending
    status = response.status_code
    if (status != 202):
        print('Failed to create a job. Check if the input data is correct.')
        return
    jobId = result['id']
    getResultsUrl = url + '&id=' + jobId

    time.sleep(timeout)
    result = getLocationJobs(getResultsUrl, 0)
    if (result):
        print(result)
        print('You can also get results by the URL - ' + getResultsUrl)
        return result
    else:
        print('You exceeded the maximal number of attempts. Try to get results later. You can do this in a browser by the URL - ' + getResultsUrl)

def getLocationJobs(url, attemptCount):
    response = requests.get(url)
    result = response.json()
    status = response.status_code
    if (status == 200):
        print('The job is succeeded. Here are the results:')
        return result
    elif (attemptCount >= maxAttempt):
        return
    elif (status == 202):
        print('The job is pending...')
        time.sleep(timeout)
        return getLocationJobs(url, attemptCount + 1)

# %%
# Get list of nurinsg home addresses
addresses = df['Name & Address'].tolist()

# Extract Coordinates form API response
data = getLocations(addresses)
# Out:
# The job is pending...
# The job is pending...
# The job is pending...
# The job is pending...
# The job is pending...
# The job is succeeded. Here are the results:
# [{'query': {'text': 'Abbeygate Care Centre 2 Leys Road Brockmoor Brierley Hill DY5 3UR', 'parsed': {'house': 'abbeygate care centre', 'housenumber': '2', 'street': 'leys road', 'suburb': 'brockmoor', 'postcode': 'dy5 3ur', 'city': 'brierley hill', 'expected_type': 'amenity'}}, 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Leys Road', 'ref': 'B4180', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'West Midlands Combined Authority', 'city': 'Dudley', 'village': 'Brierley Hill', 'postcode': 'DY5 3UR', 'suburb': 'Brockmoor', 'quarter': 'Dudley Fields', 'street': 'Leys Road', 'lon': -2.1341733, 'lat': 52.4857514, 'state_code': 'ENG', 'result_type': 'street', 'formatted': 'Leys Road, Dudley, DY5 3UR, United Kingdom', 'address_line1': 'Leys Road', 'address_line2': 'Dudley, DY5 3UR, United Kingdom', 'timezone': {'name': 'Europe/London', 'offset_STD': '+00:00', 'offset_STD_seconds': 0, 'offset_DST': '+01:00', 'offset_DST_seconds': 3600, 'abbreviation_STD': 'GMT', 'abbreviation_DST': 'BST'}, 'plus_code': '9C4VFVP8+88', 'plus_code_short': 'FVP8+88 Dudley, West Midlands Combined Authority, United Kingdom', 'rank': {'importance': 0.70001, 'popularity': 6.408931246568096, 'confidence': 0.7, 'confidence_city_level': 1, 'confidence_street_level': 1, 'match_type': 'match_by_street'}, 'place_id': '519ff87b73c91201c0593c7e141a2d3e4a40f00102f9017944160200000000c002049203094c65797320526f6164'}, {'query': {'text': 'Abbeymere 12 Eggington Road Wollaston Stourbridge DY8 2QJ', 'parsed': {'house': 'abbeymere', 'housenumber': '12', 'street': 'eggington road', 'suburb': 'wollaston', 'postcode': 'dy8 2qj', 'city': 'stourbridge', 'expected_type': 'amenity'}}, 'name': 'Wollaston', 'county': 'Dudley', 'datasource': {'sourcename': 'whosonfirst', 'attribution': "Who's On First", 'license': 'CC0', 'url': 'https://www.whosonfirst.org/docs/licenses/'}, 'city': 'Stourbridge', 'suburb': 'Wollaston', 'lon': -2.16295, 'lat': 52.4584, 'result_type': 'suburb', 'formatted': 'Wollaston, Stourbridge', 'address_line1': 'Wollaston', 'address_line2': 'Stourbridge', 'timezone': {'name': 'Europe/London', 'offset_STD': '+00:00', 'offset_STD_seconds': 0, 'offset_DST': '+01:00', 'offset_DST_seconds': 3600, 'abbreviation_STD': 'GMT', 'abbreviation_DST': 'BST'}, 'plus_code': '9C4VFR5P+9R', 'rank': {'popularity': 5.767743796626188, 'confidence': 0.25, 'confidence_city_level': 1, 'match_type': 'match_by_city_or_disrict'}, 'place_id': '51cb10c7bab84d01c059423ee8d9ac3a4a40c00205920309576f6c6c6173746f6ee2032277686f736f6e66697273743a6e65696768626f7572686f6f643a3835373931373331'}, {'query': {'text': 'Allenbrook Nursing Home 209 Spies Lane Halesowen B62 9SJ', 'parsed': {'house': 'allenbrook nursing home', 'housenumber': '209', 'street': 'spies lane', 'postcode': 'b62 9sj', 'city': 'halesowen', 'expected_type': 'amenity'}}, 'datasource': {'sourcename': 'openstreetmap', 'attribution': '© OpenStreetMap contributors', 'license': 'Open Database License', 'url': 'https://www.openstreetmap.org/copyright'}, 'name': 'Spies Lane', 'ref': 'B4043', 'country': 'United Kingdom', 'country_code': 'gb', 'state': 'England', 'county': 'West Midlands Combined Authority', 'city': 'Halesowen', 'postcode': 'B62 9AU', 'street': 'Spies Lane', 'lon': -2.0139452, 'lat': 52.4613003, 'state_code': 'ENG', 'result_type': 'street', 'formatted': 'Spies Lane, Halesowen, B62 9AU, United Kingdom', 'address_line1': 'Spies Lane', 'address_line2': 'Halesowen, B62 9AU, United Kingdom', 'timezone': {'name': 'Europe/London', 'offset_STD': '+00:00', 'offset_STD_seconds': 0, 'offset_DST': '+01:00', 'offset_DST_seconds': 3600, 'abbreviation_STD': 'GMT', 'abbreviation_DST': 'BST'}, 'plus_code': '9C4VFX6P+GC', 'plus_code_short': 'FX6P+GC Halesowen, West Midlands Combined Authority, United Kingdom', 'rank': {'importance': 0.30000999999999994, 'popularity': 6.2842 ...
# You can also get results by the URL - https://api.geoapify.com/v1/batch/geocode/search?apiKey=bf2ebb59fa014b74929f140e1ba7f866&id=f1b38cd00595431f824d3b179b8a0937

# %%
data_dict = {}
# data_dict = {d['query']['text']: [d['lat'], d['lon']] for d in data}
for d in data:
    if 'query' in d and 'text' in d['query'] and 'lat' in d and 'lon' in d:
        data_dict[d['query']['text']] = [d['lat'], d['lon']]
# Add coordinates to dataframe
df['Coordinates'] = df['Name & Address'].map(data_dict)

# %%
df.head(100)
# Out:
#                                        Name & Address  \
# 0   Abbeygate Care Centre 2 Leys Road Brockmoor Br...
# 1   Abbeymere 12 Eggington Road Wollaston Stourbri...
# 2   Allenbrook Nursing Home 209 Spies Lane Halesow...
# 3   Amberley Care Home 481-483 Stourbridge Road Ha...
# 4   Arcare For Forte 440 Birmingham New Road Bilst...
# 5    Ashbourne Care Ltd Lightwood Road Dudley DY1 2RS
# 6   Ashgrove Nursing Home 9 Dudley Wood Road Nethe...
# 7   Avondale 45 Norton Road Norton Stourbridge DY8...
# 8   Beatrice House 25 Bell Street Pensnett Brierle...
# 9   Belvidere 41-43 Stourbridge Road Holly Hall Du...
# 10  Brambles Rest Home 69-70 Vicarage Road Ambleco...
# 11         Broadway Halls The Broadway Dudley DY1 3EA
# 12  Camelot Rest Home 152 Stourbridge Road Holy Ha...
# 13           Castle View 6 Priory Road Dudley DY1 4AD
# 14  Castlewellan House 41 Moss Grove Kingswinford ...
# 15             48 Cedar Road (Voyage) Dudley, DY1 4HW
# 16  Cedars (The) 20-22 Redlake Road Pedmore Stourb...
# 17  Comberton (The) 2 King William Street Amblecot...
# 18         Edmore House 20 Oakham Road Dudley DY2 7TB
# 19  Eve House (Alphonsus) 58a Albert Street Pensne...
# 20          Gower Gardens Kent Road Halesowen B62 8PQ
# 21  Grazebrook Homes 37-39 Adshead Road Dudley DY2...
# 22  Grazebrook Homes 49-51 Adshead Road Dudley DY2...
# 23  Greenleigh 219 Wolverhampton Road Sedgley DY3 1QR
# 24  Halas Homes Wassell Road Hasbury Halesowen B63...
# 25  Highbury House Mental Health Unit Parkfield Ro...
# 26  Highfield Residential Home Stream Road Kingswi...
# 27            Highview 12 Priory Road Dudlley DY1 4AD
# 28  Hillcroft Nursing Home 135 High Street Wordsle...
# 29        Himley Manor 133 Himley Road Dudley DY1 2QF
# 30     Holly Hall 170 Stourbridge Road Dudley DY1 2ER
# 31  Holly Lodge 9 Rectory Road Oldswinford Stourbr...
# 32  Hollybush House John Corbett Drive Off Vicarag...
# 33  Hollycroft Nursing Home 8-10 Redhill Stourbrid...
# 34  Island Court 55 Bourne Street Woodsetton Dudle...
# 35  Inshore Support 27 Highfield Road Halesowen B6...
# 36  Inshore Support 10 Melbourne Road Halesowen B6...
# 37       Jubilee Court Central Drive Coseley WV14 9EJ
# 38  Kathleen House (Alphonsus) 59-61 Addiison Road...
# 39     Kiniths House 33 Kiniths Way Halesowen B62 9HJ
# 40     Lapal House Lapal Lane South Halesowen B62 0ES
# 41        Links (The) 252 The Broadway Dudley DY1 3DN
# 42  Micron House 41 Halesowen Road Netherton Dudle...
# 43  Mount (The) 226 Brettell Lane Ambecote Stourbr...
# 44        Nelson House 1-3 Nelson Road Dudley DY1 2AG
# 45  Netherton Green Nursing Home Bowling Green Roa...
# 46  New Bradley Hall Compton Drive Off Stream Road...
# 47   Norton Lodge 142 Norton Road Stourbridge DY8 2TA
# 48  Oak House (Jut us Care) 36 Oak Street Central ...
# 49         Oaklands Wartell Bank Kingswinford DY6 7QJ
# 50  Oakleigh Lodge 158-160 Stourbridge Road Dudley...
# 51  Oriel Care Home 87 Hagley Road Stoubridge DY8 1QY
# 52  Park Lane House 163 Tipton Road Woodsetton Dud...
# 53  Parkfield Grange (Stourbridge Care Limited) 31...
# 54  Pathways Care Group 44 Sedgley Road Woodsetton...
# 55  Redbrick Court 54 High Street Wordsley Stourbr...
# 56   Richmond Court 16 St James’s Road Dudley DY1 3JD
# 57     Ridgeway Court 2-4 Dudley Road Sedgley DY3 1SX
# 58  Riverside Care (Kingswinford) Ltd Wolverhampto...
# 59  Rosewood Care Home 139-143 High Street Pensnet...
# 60        Russell Court Overfield Road Dudley DY1 2NY
# 61   Safe Harbour 254 Hagley Road Stourbridge DY9 0RW
# 62   Safe Harbour 260 Hagley Road Stourbridge DY9 0RW
# 63  Stoneleigh House 166-168 Stourbridge Road Dudl...
# 64  Swiss House 41-43 Brierley Hill Road Wordsley ...
# 65     Tudor Manor 2 Brook Street Stourbridge DY8 3XF
# 66  Two Gates House 40-44 Two Gates Lane Colley Ga...
# 67   Victoria Lodge Bent Street Brierley Hill DY5 2RB
# 68  Village Nursing Home (The) 190 Commonside Brie...
# 69  Woodlands Gate Rest Home 12 Dingle Road Pedmor...
# 70  Woodview House Nursing Home Waugh Drive Hagley...
# 71  Wordsley Hall Mill Street Wordsley Stourbridge...
# 72  Wychbury Care Home 350-352 Hagley Road Pedmore...
# 73  Wyncroft House 16 Moss Grove Kingswinford DY6 9HU
#
#                                                Email   Telephone No  \
# 0                           abbeygatecare1@gmail.com   01384 571295
# 1                           abbeymere@karelink.co.uk   01384 395195
# 2              manager@allenbrooknursing\nhome.co.uk  0121 422 5844
# 3                   amberleycarehome@hotmail\n.co.uk   01384 482365
# 4                        ksharma@arcarehomes.co.u\nk   01902 880108
# 5                             ashbourne.m@fshc.co.uk   01384 242200
# 6                               cea@ashgrovecare.com   01384 413913
# 7                     avondaleresthome@hotmail.\ncom   01384 442731
# 8            beatricehouse@alphonsusse\nrvices.co.uk   01384 482963
# 9                                belvidere@gmail.com   01384 211850
# 10                  info@thebramblescarehom\ne.co.uk   01384 379034
# 11    broadwayhalls.administrato\nr@brighterkind.com   01384 215190
# 12                              cam152@hotmail.co.uk   01384 214290
# 13                    goldenseniorcare@outlook.\ncom   01384 253426
# 14                               admin@horizontc.com   01384 298321
# 15                      48CedarRoad@voyagecare.\ncom   01384 241877
# 16                           thecedars22@hotmail.com   01562 882299
# 17                 comberton@astleycarehom\nes.co.uk   01384 262027
# 18                             ann117@btinternet.com   01384 255149
# 19                evehouse@alphonsusservic\nes.co.uk   01384 482728
# 20  gowergardens.business@ki\nngsleyhealthcare.co.uk  0121 289 3965
# 21                  grazebrook@trustedhands. \nco.uk   01384 240502
# 22                  grazebrook@trustedhands. \nco.uk   01384 255171
# 23                   greenleigh@select-\ngroup.co.uk   01902 664023
# 24                             info@halashomes.co.uk  0121 550 8778
# 25             highbury.house@rushcliffec\nare.co.uk   01384 354455
# 26               info@highfieldres.onmicros\noft.com   01384 288870
# 27                       highview.home12@gmail.co\nm   01384 258502
# 28                 hillcroft@astleycarehomes.c\no.uk   01384 271317
# 29                         manager@himleymanor.co\nm   01384 238588
# 30                    hollyhall@select-\ngroup.co.uk   01384 252219
# 31                   Info@hollylodgecarehome.c\no.uk   01384 373306
# 32                      hollybush.house@shaw.co.\nuk   01384 442782
# 33                    manager@hollycroftcare.co.\nuk   01384 394341
# 34           islandcourtmanager@select\n-group.co.uk   01902 886300
# 35                    Ruth@inshoresupportltd.co.\nuk   01384 410581
# 36             rachealpace@inshoresuppo\nrtltd.co.uk  0121 501 3389
# 37                 jubileecourt@select-\ngroup.co.uk   01902 883426
# 38           kathleenhouse@alphonsuss\nervices.co.uk    01384 70187
# 39                    enquiries@kinithshouse.co.\nuk  0121 559 7091
# 40                            admin@lapalhouse.co.uk  0121 503 0326
# 41                     TheLinks.Manager@shaw.c\no.uk   01384 459651
# 42                  steph@activecareservices.c\no.uk   01384 230504
# 43                         themount226@hotmail.co\nm   01384 265955
# 44                             stephen.kular@nhs.net   01384 237717
# 45        homemanager.nethertongr\neen@advinia.co.uk   01384 410120
# 46           newbradleyhall@bchg.co.uk  01384 278689            NaN
# 47                       nischapritchard@yahoo.co\nm   01384 376666
# 48                           justuscareltd@gmail.com   01384 413622
# 49                             dpsahni@hotmail.co.uk   01384 291070
# 50                 admin@oakleigh-\nhealthcare.co.uk   01384 232482
# 51                              info@orielcare.co.uk   01384 375867
# 52                        parklanehome@outlook.co\nm   01902 884967
# 53                  parkfield.admin@cinnamon\ncc.com   01384 470358
# 54                   enquiries@pathways4care.c\no.uk   01902 887630
# 55                               admin@sclcare.co.uk   01384 485444
# 56                 richmondcourtdudley@outloo\nk.com   01384 254442
# 57                     manager@ridgewaycares.co.\nuk   01902 883130
# 58                    HM@riversidecarecentre.co\n.uk   01384 404233
# 59                    manager@rosewoodcareho\nme.com    01384 77441
# 60          manager@russell-court.com  0744 220 6657            NaN
# 61                     admin@safeharbourcare.co\n.uk   01562 888125
# 62                 clientadmin@safeharbourca\nre.com   01384 885018
# 63                    stoneleigh_house@hotmail.\ncom   01384 235590
# 64                  swiss.house@select-\ngroup.co.uk   01384 573110
# 65                             regmanager1@yahoo.com   01384 379165
# 66                      max_wellington@outlook.c\nom   01384 567448
# 67              victoriamanager@select-\ngroup.co.uk   01384 572567
# 68        kerryjackson@thevillagenur\nsinghome.co.uk   01384 884499
# 69                           woodlands@sclcare.co.uk   01562 885546
# 70                               woodview@shaw.co.uk  0121 585 6440
# 71     manager.wordsleyhall@min\nstercaregroup.co.uk   01384 571606
# 72                               daniel@wychcare.com   01562 885106
# 73                     manager@wyncrofthouse.c\no.uk   01384 291688
#
#                                 Age Range  \
# 0                                 Age 65+
# 1                                Ages 65+
# 2                                Ages 55+
# 3                                Ages 65+
# 4                                     18+
# 5                                Ages 65+
# 6                                Ages 65+
# 7                                Ages 65+
# 8                              Not Stated
# 9                                Ages 55+
# 10                               Ages 50+
# 11                               Ages 65+
# 12                               Ages 18+
# 13                               Ages 18+
# 14                               Ages 65+
# 15                               Under 65
# 16                Ages 65+ \nNo \nSmoking
# 17                               Ages 18+
# 18                               Ages 65+
# 19                                    18+
# 20                               Ages 65+
# 21                                  18-65
# 22                                  18-65
# 23                               Ages 65+
# 24                                    18+
# 25                               Ages 18+
# 26                               Ages 65+
# 27                               Ages 65+
# 28                               Ages 60+
# 29                               Ages 65+
# 30                                    NaN
# 31                               Ages 65+
# 32                               Ages 65+
# 33                               Ages 65+
# 34                                    65+
# 35                             Not Stated
# 36                             Not Stated
# 37                               Under 65
# 38                             Not Stated
# 39                                    18+
# 40                                    65+
# 41                                    18+
# 42                                    65+
# 43                               Ages 18+
# 44                               Ages 65+
# 45                               Ages 60+
# 46                               Ages 18+
# 47                               Ages 65+
# 48                                    18+
# 49                               Ages 50+
# 50                                  18-65
# 51  Mobile \nwith one \ncarer  \nAges 65+
# 52                               Ages 60+
# 53                               Ages 60+
# 54                                    18+
# 55                               Ages 60+
# 56                   Ages from \n50 – 150
# 57                               Ages 65+
# 58                                    18+
# 59                               Ages 55+
# 60                             Ages 50+
# 61                           Not \nStated
# 62                           Not \nStated
# 63                                    65+
# 64                           Not \nStated
# 65                             Ages 60+
# 66                             Ages 65+
# 67                             Ages 65+
# 68                             Ages 50+
# 69                             Ages 60+
# 70                             Ages 65+
# 71                             Ages 65+
# 72                             Ages 65+
# 73                             Ages 65+
#
#                                    CQC Registered For  \
# 0   Dementia \nMental Health Condition \nOld Age \...
# 1   Dementia \nMental Health Condition \nOld Age \...
# 2   Dementia \nMental Health Condition \nNo Medica...
# 3                                  Dementia \nOld Age
# 4   Learning Disability \nMental Health Condition ...
# 5                                  Dementia \nOld Age
# 6             Dementia \nOld Age \nSensory Impairment
# 7                                             Old Age
# 8                                 Learning Disability
# 9   Dementia \nDetention Under Mental \nHealth Act...
# 10  Dementia \nOld Age \nPhysical Disability \nYou...
# 11           Dementia \nOld Age \nPhysical Disability
# 12                                 Dementia \nOld Age
# 13                                 Dementia \nOld Age
# 14                                            Old Age
# 15  Learning Disability \nMental Health Condition ...
# 16                                 Dementia \nOld Age
# 17  Dementia \nOld Age \nPhysical Disability \nYou...
# 18                                            Old Age
# 19  Learning Disability \nMental Health Condition ...
# 20  Dementia \nMental Health Condition \nOld Age \...
# 21  Dementia \nLearning Disability \nPhysical Disa...
# 22  Dementia \nLearning Disability \nPhysical Disa...
# 23           Dementia \nOld Age \nPhysical Disability
# 24                                Learning Disability
# 25  Detention Under Mental \nHealth Act \nLearning...
# 26  Dementia \nOld Age \nPhysical Disability \nSen...
# 27  Dementia \nMental Health Condition \nOld Age \...
# 28  Dementia \nLearning Disability \nNo Medical In...
# 29  Dementia \nEating Disorders \nOld Age \nPhysic...
# 30                                                NaN
# 31  Dementia \nOld Age \nPhysical Disability \nSen...
# 32                                 Dementia \nOld Age
# 33  Dementia \nNo Medical Intervention \nOld Age \...
# 34  Dementia \nPhysical Disabilities \nSensory Imp...
# 35      Learning Disability \nMental Health Condition
# 36                                Learning Disability
# 37  Learning Disability \nMental Health Condition ...
# 38        Learning Disabilities \nPhysical Disability
# 39                                Learning Disability
# 40                      Old Age \nPhysical Disability
# 41      Learning Disability \nMental Health Condition
# 42                                 Dementia \nOld Age
# 43                                 Dementia \nOld Age
# 44                                 Dementia \nOld Age
# 45           Dementia \nOld Age \nPhysical Disability
# 46                                 Dementia \nOld Age
# 47                      Old Age \nPhysical Disability
# 48  Dementia \nEating Disorders \nLearning Disabil...
# 49  Dementia \nMental Health Condition \nOld Age \...
# 50  Learning Disability \nMental Health Condition ...
# 51  Dementia \nOld Age \nPhysical Disability \nSen...
# 52                                 Dementia \nOld Age
# 53  Dementia \nOld Age \nPhysical Disability \nSen...
# 54  Learning Disability \nOld Age \nPhysical Disab...
# 55  Dementia \nOld Age \nPhysical Disability \nSen...
# 56  Dementia \nMental Health Condition \nOld Age \...
# 57  Dementia \nOld Age \nPhysical Disability \nSen...
# 58  Dementia \nMental Health Condition \nPhysical ...
# 59  Dementia \nMental Health Condition \nOld Age \...
# 60  Old Age \nPhysical Disability \nSensory Impair...
# 61                                Learning Disability
# 62                                Learning Disability
# 63  Dementia \nLearning Disability \nMental Health...
# 64  Learning Disability \nPhysical Disability \nYo...
# 65            Old Age \nPhysical Disability, Dementia
# 66  Old Age \nPhysical Disability \nSensory Impair...
# 67             Old Age \nSensory Impairment, Dementia
# 68  Mental Health Condition \nOld Age \nPhysical D...
# 69  Old Age \nPhysical Disability \nSensory Impair...
# 70  C\nMental Health Condition \nOld Age \nCG Comm...
# 71                                  Old Age, Dementia
# 72                                          , Old Age
# 73                                  Old Age, Dementia
#
#                               Provide \nNursing  Capacity Post Code  \
# 0                                            No      17.0   DY5 3UR
# 1                                            No      18.0   DY8 2QJ
# 2                                           Yes      36.0   B62 9SJ
# 3                                            No      25.0   DY5 1LB
# 4                                            No       9.0  WV14 9QB
# 5                                            No      38.0   DY1 2RS
# 6                                           Yes      57.0   DY2 0DA
# 7                                            No      15.0   DY8 2AH
# 8                                            No       3.0   DY5 4HG
# 9                                            No      28.0   DY1 2DH
# 10                                           No      35.0   DY8 4JA
# 11                                          Yes      83.0   DY1 3EA
# 12                                           No      33.0   DY1 2ER
# 13                                           No      13.0   DY1 4AD
# 14                                           No      18.0   DY6 9HP
# 15                                           No       9.0   DY1 4HW
# 16                                           No      22.0   DY9 0SA
# 17                                          Yes      36.0   DY8 4EP
# 18                                           No      18.0   DY2 7TB
# 19                                           No       5.0   DY5 4HW
# 20                                           No      66.0   B62 8PQ
# 21                                           No       9.0   DY2 8SS
# 22                                           No       9.0   DY2 8SS
# 23                                           No      35.0   DY3 1QR
# 24                                           No      30.0   B63 4JX
# 25  Yes \nADULT \nMENTAL \nHEALTH \nUNIT \nONLY      21.0   DY8 1HB
# 26                                           No      13.0   DY6 9PB
# 27                                           No      23.0   DY1 4AD
# 28                                          Yes      28.0   DY8 5QS
# 29                                           No      51.0   DY1 2QF
# 30                                          NaN       NaN   DY1 2ER
# 31                                           No      23.0   DY8 2HA
# 32                           Yes \n(NHS \nOnly)      24.0   DY8 4HZ
# 33                                          Yes      37.0   DY8 1ND
# 34                                          Yes      55.0  WV14 9HN
# 35                                           No       3.0   B63 2DH
# 36                                           No       3.0   B63 2NB
# 37                                          Yes      30.0  WV14 9EJ
# 38                                           No      15.0   DY5 3RR
# 39                                           No      15.0   B62 9HJ
# 40                                           No      41.0   B62 0ES
# 41                                           No       5.0   DY1 3DN
# 42                                           No      10.0   DY2 9QD
# 43                                           No      18.0   DY8 4BQ
# 44                                           No      21.0   DY1 2AG
# 45                                          Yes     120.0   DY2 9LY
# 46                                           No      66.0   DY6 9NP
# 47                                           No      18.0   DY8 2TA
# 48                                           No       4.0   DY2 9LJ
# 49                                          Yes      40.0   DY6 7QJ
# 50                                           No      19.0   DY1 2ER
# 51                                           No      29.0   DY8 1QY
# 52                                           No      30.0   DY3 1AB
# 53                                           No      80.0   DY8 1QH
# 54                                           No       5.0   DY1 4NG
# 55                                           No      37.0   DY8 5SD
# 56                                           No      21.0   DY1 3JD
# 57                                           No      39.0   DY3 1SX
# 58                                           No      24.0   DY6 7DA
# 59                                           No      43.0   DY5 4EA
# 60                                          Yes      42.0   DY1 2NY
# 61                                           No       6.0   DY9 0RW
# 62                                           No       4.0   DY9 0RW
# 63                                           No      24.0   DY1 2ER
# 64                                           No      10.0   DY8 5SJ
# 65                                           No      22.0   DY8 3XF
# 66                                           No      32.0   B83 2LJ
# 67                                           No      63.0   DY5 2RB
# 68                                          Yes      90.0   DY5 4AA
# 69                                           No      20.0   DY9 0RS
# 70                                          Yes      24.0   B63 1EN
# 71                                           No      41.0   DY8 5SX
# 72                                           No      42.0   DY9 0QY
# 73                                          Yes      38.0   DY6 9HU
#
#             Care Home Name  Min Age  Max Age  \
# 0          Abbeygate Care      65.0      NaN
# 1               Abbeymere      65.0      NaN
# 2      Allenbrook Nursing      55.0      NaN
# 3      Amberley Care Home      65.0      NaN
# 4        Arcare For Forte      18.0      NaN
# 5      Ashbourne Care Ltd      65.0      NaN
# 6        Ashgrove Nursing      65.0      NaN
# 7               Avondale       65.0      NaN
# 8          Beatrice House       NaN      NaN
# 9               Belvidere      55.0      NaN
# 10     Brambles Rest Home      50.0      NaN
# 11         Broadway Halls      65.0      NaN
# 12      Camelot Rest Home      18.0      NaN
# 13            Castle View      18.0      NaN
# 14     Castlewellan House      65.0      NaN
# 15          48 Cedar Road      65.0      NaN
# 16           Cedars (The)      65.0      NaN
# 17        Comberton (The)      18.0      NaN
# 18           Edmore House      65.0      NaN
# 19              Eve House      18.0      NaN
# 20          Gower Gardens      65.0      NaN
# 21       Grazebrook Homes      18.0     65.0
# 22       Grazebrook Homes      18.0     65.0
# 23             Greenleigh      65.0      NaN
# 24            Halas Homes      18.0      NaN
# 25         Highbury House      18.0      NaN
# 26  Highfield Residential      65.0      NaN
# 27              Highview       65.0      NaN
# 28      Hillcroft Nursing      60.0      NaN
# 29           Himley Manor      65.0      NaN
# 30             Holly Hall       NaN      NaN
# 31            Holly Lodge      65.0      NaN
# 32       Hollybush House       65.0      NaN
# 33     Hollycroft Nursing      65.0      NaN
# 34           Island Court      65.0      NaN
# 35        Inshore Support       NaN      NaN
# 36        Inshore Support       NaN      NaN
# 37          Jubilee Court      65.0      NaN
# 38         Kathleen House       NaN      NaN
# 39          Kiniths House      18.0      NaN
# 40            Lapal House      65.0      NaN
# 41            Links (The)      18.0      NaN
# 42           Micron House      65.0      NaN
# 43            Mount (The)      18.0      NaN
# 44           Nelson House      65.0      NaN
# 45        Netherton Green      60.0      NaN
# 46       New Bradley Hall      18.0      NaN
# 47           Norton Lodge      65.0      NaN
# 48              Oak House      18.0      NaN
# 49               Oaklands      50.0      NaN
# 50         Oakleigh Lodge      18.0     65.0
# 51        Oriel Care Home      65.0      NaN
# 52        Park Lane House      60.0      NaN
# 53      Parkfield Grange       60.0      NaN
# 54    Pathways Care Group      18.0      NaN
# 55         Redbrick Court      60.0      NaN
# 56         Richmond Court      50.0      NaN
# 57         Ridgeway Court      65.0      NaN
# 58         Riverside Care      18.0      NaN
# 59     Rosewood Care Home      55.0      NaN
# 60          Russell Court      50.0      NaN
# 61           Safe Harbour       NaN      NaN
# 62           Safe Harbour       NaN      NaN
# 63       Stoneleigh House      65.0      NaN
# 64            Swiss House       NaN      NaN
# 65            Tudor Manor      60.0      NaN
# 66        Two Gates House      65.0      NaN
# 67         Victoria Lodge      65.0      NaN
# 68   Village Nursing Home      50.0      NaN
# 69    Woodlands Gate Rest      60.0      NaN
# 70         Woodview House      65.0      NaN
# 71          Wordsley Hall      65.0      NaN
# 72     Wychbury Care Home      65.0      NaN
# 73         Wyncroft House      65.0      NaN
#
#                                   Coordinates
# 0                    [52.4857514, -2.1341733]
# 1                         [52.4584, -2.16295]
# 2                    [52.4613003, -2.0139452]
# 3                    [52.4927718, -2.1164204]
# 4                     [52.5481562, -2.094362]
# 5                      [52.517467, -2.101861]
# 6                    [52.4777428, -2.0859231]
# 7                     [52.4453886, -2.157669]
# 8                      [52.4809461, -2.12446]
# 9                    [52.5037783, -2.1017361]
# 10                   [52.4640096, -2.1481652]
# 11  [52.515554949999995, -2.0877722990597367]
# 12                   [52.5028747, -2.1047859]
# 13                    [52.513868, -2.0858346]
# 14                   [52.5015863, -2.1698679]
# 15                           [52.5, -2.08333]
# 16                   [52.4387806, -2.1367573]
# 17                   [52.4709654, -2.1499568]
# 18         [52.50345735, -2.0725455852966848]
# 19                       [52.48173, -2.12139]
# 20           [52.4594051, -2.025260015283357]
# 21                   [52.5017384, -2.0828334]
# 22                   [52.5017384, -2.0828334]
# 23                   [52.5931208, -2.1066216]
# 24                                        NaN
# 25                   [52.4548487, -2.1411762]
# 26                   [52.4871586, -2.1623606]
# 27                      [51.11129, -0.864748]
# 28                   [52.4831312, -2.1621007]
# 29                   [52.5122987, -2.1024108]
# 30                   [52.5028747, -2.1047859]
# 31                     [52.446726, -2.138347]
# 32                     [52.464863, -2.149516]
# 33                     [52.452297, -2.140777]
# 34                   [52.5388878, -2.1008776]
# 35                   [52.4583393, -2.0807963]
# 36                   [52.4561525, -2.0496545]
# 37                     [52.548357, -2.083124]
# 38                       [52.48173, -2.12139]
# 39                   [52.4730054, -2.0272562]
# 40                   [52.4445543, -2.0226654]
# 41                     [52.515211, -2.087861]
# 42                   [52.4921232, -2.0836324]
# 43  [52.471036999999995, -2.1544941590377498]
# 44                   [52.5106726, -2.0943908]
# 45                    [52.482742, -2.0763456]
# 46                       [52.49755, -2.16889]
# 47                   [52.4436731, -2.1594272]
# 48                     [52.493425, -2.083401]
# 49                   [52.5012219, -2.1650633]
# 50                   [52.5028747, -2.1047859]
# 51                     [52.451177, -2.141871]
# 52                    [52.5358986, -2.108205]
# 53            [52.4529282, -2.14260599108629]
# 54                   [52.5318036, -2.0878087]
# 55                   [52.4777139, -2.1593561]
# 56                   [52.5124201, -2.0905432]
# 57                   [52.5354323, -2.1190688]
# 58                   [36.196417, -115.170299]
# 59           [52.4728913, -2.106248001784807]
# 60                           [52.5, -2.08333]
# 61                   [52.4327421, -2.1301692]
# 62                   [52.4327421, -2.1301692]
# 63                   [52.5028747, -2.1047859]
# 64                   [52.4787384, -2.1551871]
# 65                   [52.4546569, -2.1563455]
# 66                       [52.44859, -2.04938]
# 67                   [52.4859273, -2.1231611]
# 68                   [52.4930732, -2.1326086]
# 69                   [52.4434178, -2.1320989]
# 70                   [52.4356855, -2.0820804]
# 71                   [52.4780241, -2.1562237]
# 72                   [52.4327421, -2.1301692]
# 73                   [52.5025546, -2.1702452]

# %%
# Showing any coordinates with a null value to be able to manually check
# and fix them.
df[df['Coordinates'].isnull()]
# Out:
#                                        Name & Address                  Email  \
# 24  Halas Homes Wassell Road Hasbury Halesowen B63...  info@halashomes.co.uk
#
#      Telephone No Age Range   CQC Registered For Provide \nNursing  Capacity  \
# 24  0121 550 8778       18+  Learning Disability                No      30.0
#
#    Post Code Care Home Name  Min Age  Max Age Coordinates
# 24   B63 4JX   Halas Homes      18.0      NaN         NaN

# %%
# print name and address from row number 24
print(df.iloc[58]['Name & Address'])
# Out:
# Riverside Care (Kingswinford) Ltd Wolverhampton Road Wall Heath Kingswinford DY6 7DA

# %%
# Manually fixing the coordinates for row 24
# Corrdinates obtaine form the web
df.at[24, 'Coordinates'] = [52.44464220440522, -2.0660808868916276]

# %%
# Splitting the coordinates into two columns
df[['Latitude', 'Longitude']] = pd.DataFrame(df['Coordinates'].tolist(), index=df.index)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74 entries, 0 to 73
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name & Address      74 non-null     object
#  1   Email               74 non-null     object
#  2   Telephone No        72 non-null     object
#  3   Age Range           73 non-null     object
#  4   CQC Registered For  73 non-null     object
#  5   Provide
# Nursing    73 non-null     object
#  6   Capacity            73 non-null     float64
#  7   Post Code           74 non-null     object
#  8   Care Home Name      74 non-null     object
#  9   Min Age             66 non-null     float64
#  10  Max Age             3 non-null      float64
#  11  Coordinates         74 non-null     object
#  12  Latitude            74 non-null     float64
#  13  Longitude           74 non-null     float64
# dtypes: float64(5), object(9)
# memory usage: 8.2+ KB

# %%
# Save the data to a new csv file
df.to_csv('../data/nhomes_cleaned_coordinates.csv', index=False)

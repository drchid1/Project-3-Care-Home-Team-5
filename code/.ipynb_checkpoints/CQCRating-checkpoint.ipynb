# %% [markdown]
# ## API Featching for CQC rating in Dudley Care Homes

# %%
import requests
import json

# %%
# Base URL for the CQC API
base_url = "https://api.service.cqc.org.uk/public/v1/locations"

# Parameters for the API request
params = {
    "localAuthority": "Dudley",  
    "careHome": "Y",            
    "perPage": 100               
}

# Subscription key for authentication
subscription_key = "6c0491618d764af0a892e9a51c9666ce"

# Headers for the API request
headers = {
    # User-Agent header to avoid getting blocked
    "User-Agent": "Mozilla/5.0",  
    # Subscription key for authentication
    "Ocp-Apim-Subscription-Key": subscription_key  
}

def fetch_data(url, params, headers):
    """
    Fetch data from the API.
    """
    response = requests.get(url, params=params, headers=headers)
    if response.status_code == 200:
        # Return the JSON response if successful
        return response.json()  
    return None

def fetch_care_home_ratings(location_id, headers):
    """
    Fetch overall ratings for a care home by its location ID.
    """
    url = f"https://api.service.cqc.org.uk/public/v1/locations/{location_id}"
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        data = response.json()
        rating = data.get('currentRatings', {}).get('overall', {}).get('rating')
        return rating
    return None

# Fetch data from the CQC API
data = fetch_data(base_url, params, headers)

# Check if data was successfully fetched
if data:
    # Process and print the data as needed
    for location in data.get('locations', []):
        name = location.get('locationName')
        location_id = location.get('locationId')
        rating = fetch_care_home_ratings(location_id, headers)
        if rating is not None:
            print(f"Care Home: {name}, Rating: {rating}")
# Out:
# Care Home: Cygnet House, Rating: Good
# Care Home: 60 Olive Lane, Rating: Good
# Care Home: Arcare for Forte Limited, Rating: Good
# Care Home: Hollybush House Nursing Home, Rating: Good
# Care Home: Woodview House Nursing Home, Rating: Requires improvement
# Care Home: Commonside Care Limited - 73 Commonside, Rating: Good
# Care Home: Stanford House, Rating: Requires improvement
# Care Home: Tudor Manor, Rating: Inadequate
# Care Home: Attwood Street, Rating: Good
# Care Home: Langstone Road, Rating: No published rating
# Care Home: Stickley Lane, Rating: Requires improvement
# Care Home: Edmore House Residential Home, Rating: Good
# Care Home: Belvidere Residential Care Home, Rating: Requires improvement
# Care Home: Woodlands Gate Rest Home, Rating: Good
# Care Home: Two Gates House, Rating: Good
# Care Home: Eve House, Rating: No published rating
# Care Home: Nelson House, Rating: Requires improvement
# Care Home: Mr and Mrs O'Donnell, Rating: Inadequate
# Care Home: Halas Homes, Rating: Good
# Care Home: Castlewellan House, Rating: Good
# Care Home: Everley Residential Home, Rating: Requires improvement
# Care Home: Kathleen House, Rating: Good
# Care Home: Safeharbour (260 Hagley Road), Rating: Good
# Care Home: Safeharbour (254 Hagley Road), Rating: Good
# Care Home: Summerfield Care Home, Rating: No published rating
# Care Home: The Mount Care Home, Rating: No published rating
# Care Home: Ridgeway Court Care Home, Rating: Good
# Care Home: The Village Nursing Home, Rating: Requires improvement
# Care Home: Chapel Street, Rating: No published rating
# Care Home: Havacre Lane, Rating: No published rating
# Care Home: Inshore Support Limited - 27 Highfield Road, Rating: Good
# Care Home: Inshore Support Limited - 10 Melbourne Road, Rating: Good
# Care Home: Pool View, Rating: No published rating
# Care Home: Wrens Croft, Rating: No published rating
# Care Home: Brambles Rest Home, Rating: Requires improvement
# Care Home: RNID Action on Hearing Loss 60 Olive Lane, Rating: Good
# Care Home: Castle Meadows, Rating: No published rating
# Care Home: Nethercrest Nursing Home, Rating: Requires improvement
# Care Home: Nethercrest Residential Home, Rating: No published rating
# Care Home: St Marks House, Rating: No published rating
# Care Home: Oaklands Care Home, Rating: Good
# Care Home: Abercarn Care Home, Rating: Good
# Care Home: Wyncroft House, Rating: Requires improvement
# Care Home: Wychbury Care Home, Rating: Good
# Care Home: Comberton Nursing Home, Rating: Requires improvement
# Care Home: Hillcroft Nursing Home, Rating: Requires improvement
# Care Home: Alexandra House Care Home - Brierley Hill, Rating: No published rating
# Care Home: Woodlands, Rating: Requires improvement
# Care Home: Rosemary Retirement Home, Rating: Inadequate
# Care Home: Wordsley Hall, Rating: Good
# Care Home: The Cherries, Rating: Good
# Care Home: Highbury House Mental Health Unit, Rating: Requires improvement
# Care Home: Ashgrove Nursing Home, Rating: No published rating
# Care Home: Redbrick Court, Rating: No published rating
# Care Home: Hollybush House Nursing Home, Rating: Good
# Care Home: Gorstyfield Nursing Home, Rating: No published rating
# Care Home: Woodview House Nursing Home, Rating: Good
# Care Home: Harper House - Stourbridge, Rating: Good
# Care Home: Park Lane House, Rating: Good
# Care Home: Netherton Green Care Home, Rating: Requires improvement
# Care Home: Beaconhurst, Rating: Good
# Care Home: Grazebrook Homes - 39 Adshead Road, Rating: Good
# Care Home: Grazebrook Homes - 49 Adshead Road, Rating: Good
# Care Home: Grazebrook Homes - 3 Paradise, Rating: No published rating
# Care Home: Annabel House, Rating: No published rating
# Care Home: Castlewellan House, Rating: Requires improvement
# Care Home: Gower Gardens Residential Care Home, Rating: Good
# Care Home: The Links, Rating: Good
# Care Home: Voyage Limited - 48 Cedar Road, Rating: No published rating
# Care Home: Stoneleigh House, Rating: Requires improvement
# Care Home: Kiniths House, Rating: Good
# Care Home: Holbeche House, Rating: No published rating
# Care Home: New Bradley Hall, Rating: No published rating
# Care Home: New Swinford Hall, Rating: No published rating
# Care Home: Russell Court, Rating: Requires improvement
# Care Home: Tiled House, Rating: Good
# Care Home: New Bridge House, Rating: No published rating
# Care Home: 44 Sedgley Road, Rating: Good
# Care Home: Camelot Rest Home, Rating: No published rating
# Care Home: Holly Lodge, Rating: Good
# Care Home: Richmond Court Residential Home, Rating: Good
# Care Home: Broadway Halls Care Home, Rating: Requires improvement
# Care Home: The Mount Residential Home, Rating: Requires improvement
# Care Home: Ashgrove Nursing Home, Rating: Requires improvement
# Care Home: Hollycroft Nursing Home, Rating: Requires improvement
# Care Home: The Keepings, Rating: Good
# Care Home: Swan Village Care Services - 44 Sedgley Road, Rating: No published rating
# Care Home: Swan Village Care Services - 46 Sedgley Road, Rating: No published rating
# Care Home: Abbeymere Care Centre, Rating: Good
# Care Home: Abbeygate Care Centre, Rating: No published rating

# %%
# Iterate over the locations array and extract information
for location in data.get('locations', []):
    name = location.get('locationName')
    postal_code = location.get('postalCode')
    rating = location.get('rating')  # Assuming that 'rating' is a key in the location dictionary
    print(f"Care Home: {name}, Postal Code: {postal_code}, Rating: {rating}")
# Out:
# Care Home: Cygnet House, Postal Code: DY8 3UU, Rating: None
# Care Home: Parkfield Grange, Postal Code: DY8 1QH, Rating: None
# Care Home: 60 Olive Lane, Postal Code: B62 8LZ, Rating: None
# Care Home: Arcare for Forte Limited, Postal Code: WV14 9QB, Rating: None
# Care Home: Hollybush House Nursing Home, Postal Code: DY8 4HZ, Rating: None
# Care Home: Woodview House Nursing Home, Postal Code: B63 1EN, Rating: None
# Care Home: Commonside Care Limited - 73 Commonside, Postal Code: DY5 4AJ, Rating: None
# Care Home: Stanford House, Postal Code: DY3 1ST, Rating: None
# Care Home: Tudor Manor, Postal Code: DY8 3XF, Rating: None
# Care Home: Attwood Street, Postal Code: B63 3UE, Rating: None
# Care Home: Langstone Road, Postal Code: DY1 2NJ, Rating: None
# Care Home: Stickley Lane, Postal Code: DY3 2JQ, Rating: None
# Care Home: Edmore House Residential Home, Postal Code: DY2 7TB, Rating: None
# Care Home: Belvidere Residential Care Home, Postal Code: DY1 2DH, Rating: None
# Care Home: Woodlands Gate Rest Home, Postal Code: DY9 0RS, Rating: None
# Care Home: Two Gates House, Postal Code: B63 2LJ, Rating: None
# Care Home: Beatrice House, Postal Code: DY5 4HG, Rating: None
# Care Home: Eve House, Postal Code: DY5 4HW, Rating: None
# Care Home: Nelson House, Postal Code: DY1 2AG, Rating: None
# Care Home: Mr and Mrs O'Donnell, Postal Code: DY6 8AY, Rating: None
# Care Home: Halas Homes, Postal Code: B63 4JX, Rating: None
# Care Home: Castlewellan House, Postal Code: DY6 9HP, Rating: None
# Care Home: Everley Residential Home, Postal Code: B63 2PQ, Rating: None
# Care Home: Kathleen House, Postal Code: DY5 3RR, Rating: None
# Care Home: Safeharbour (260 Hagley Road), Postal Code: DY9 0RW, Rating: None
# Care Home: Safeharbour (254 Hagley Road), Postal Code: DY9 0RW, Rating: None
# Care Home: Summerfield Care Home, Postal Code: DY1 1RD, Rating: None
# Care Home: Amberley Care Home, Postal Code: DY5 1LB, Rating: None
# Care Home: The Mount Care Home, Postal Code: DY8 4BQ, Rating: None
# Care Home: Ridgeway Court Care Home, Postal Code: DY3 1SX, Rating: None
# Care Home: The Village Nursing Home, Postal Code: DY5 4AA, Rating: None
# Care Home: Chapel Street, Postal Code: DY5 2DW, Rating: None
# Care Home: Havacre Lane, Postal Code: WV14 9NP, Rating: None
# Care Home: Inshore Support Limited - 27 Highfield Road, Postal Code: B63 2DH, Rating: None
# Care Home: Inshore Support Limited - 10 Melbourne Road, Postal Code: B63 3NB, Rating: None
# Care Home: Pool View, Postal Code: DY1 3SN, Rating: None
# Care Home: Wrens Croft, Postal Code: DY1 3SN, Rating: None
# Care Home: Brambles Rest Home, Postal Code: DY8 4JA, Rating: None
# Care Home: RNID Action on Hearing Loss 60 Olive Lane, Postal Code: B62 8LZ, Rating: None
# Care Home: Castle Meadows, Postal Code: DY1 2RU, Rating: None
# Care Home: Nethercrest Nursing Home, Postal Code: DY2 0PH, Rating: None
# Care Home: Nethercrest Residential Home, Postal Code: DY2 0PH, Rating: None
# Care Home: Glebelands, Postal Code: DY8 3AZ, Rating: None
# Care Home: St Marks House, Postal Code: DY9 8SN, Rating: None
# Care Home: Oaklands Care Home, Postal Code: DY6 7QJ, Rating: None
# Care Home: Abercarn Care Home, Postal Code: DY5 4RS, Rating: None
# Care Home: Wyncroft House, Postal Code: DY6 9HU, Rating: None
# Care Home: Wychbury Care Home, Postal Code: DY9 0QY, Rating: None
# Care Home: Comberton Nursing Home, Postal Code: DY8 4EP, Rating: None
# Care Home: Hillcroft Nursing Home, Postal Code: DY8 5QS, Rating: None
# Care Home: Alexandra House Care Home - Brierley Hill, Postal Code: DY5 4EA, Rating: None
# Care Home: Woodlands, Postal Code: DY8 4QE, Rating: None
# Care Home: Rosemary Retirement Home, Postal Code: DY8 4NP, Rating: None
# Care Home: Wordsley Hall, Postal Code: DY8 5SX, Rating: None
# Care Home: The Cherries, Postal Code: DY6 0HJ, Rating: None
# Care Home: Riverside Care Centre, Postal Code: DY6 7DA, Rating: None
# Care Home: Highbury House Mental Health Unit, Postal Code: DY8 1HB, Rating: None
# Care Home: Ashbourne Residential Home - Dudley, Postal Code: DY1 2RS, Rating: None
# Care Home: Ashgrove Nursing Home, Postal Code: DY2 0DA, Rating: None
# Care Home: Redbrick Court, Postal Code: DY8 5SD, Rating: None
# Care Home: Hollybush House Nursing Home, Postal Code: DY8 4HZ, Rating: None
# Care Home: Gorstyfield Nursing Home, Postal Code: DY8 5ST, Rating: None
# Care Home: Woodview House Nursing Home, Postal Code: B63 1EN, Rating: None
# Care Home: Harper House - Stourbridge, Postal Code: DY8 3UZ, Rating: None
# Care Home: Park Lane House, Postal Code: DY3 1AB, Rating: None
# Care Home: Netherton Green Care Home, Postal Code: DY2 9LY, Rating: None
# Care Home: Beaconhurst, Postal Code: DY3 1LF, Rating: None
# Care Home: Grazebrook Homes - 39 Adshead Road, Postal Code: DY2 8ST, Rating: None
# Care Home: Grazebrook Homes - 49 Adshead Road, Postal Code: DY2 8ST, Rating: None
# Care Home: Grazebrook Homes - 3 Paradise, Postal Code: DY2 8SH, Rating: None
# Care Home: Annabel House, Postal Code: DY8 3XR, Rating: None
# Care Home: Castlewellan House, Postal Code: DY6 9HP, Rating: None
# Care Home: Gower Gardens Residential Care Home, Postal Code: B62 8PQ, Rating: None
# Care Home: The Links, Postal Code: DY1 3DN, Rating: None
# Care Home: Voyage Limited - 48 Cedar Road, Postal Code: DY1 4HW, Rating: None
# Care Home: GlassHouse College, Postal Code: DY8 4HF, Rating: None
# Care Home: Stoneleigh House, Postal Code: DY1 2ER, Rating: None
# Care Home: Kiniths House, Postal Code: B62 9HJ, Rating: None
# Care Home: Holbeche House, Postal Code: DY6 7DA, Rating: None
# Care Home: Wyncroft House, Postal Code: DY6 9HU, Rating: None
# Care Home: New Bradley Hall, Postal Code: DY6 9NP, Rating: None
# Care Home: New Swinford Hall, Postal Code: DY9 7PE, Rating: None
# Care Home: Russell Court, Postal Code: DY1 2NY, Rating: None
# Care Home: Shenstone, Postal Code: B62 8PF, Rating: None
# Care Home: Tiled House, Postal Code: DY5 4LE, Rating: None
# Care Home: Amblecote House, Postal Code: DY8 4ES, Rating: None
# Care Home: New Bridge House, Postal Code: WV14 9DS, Rating: None
# Care Home: 44 Sedgley Road, Postal Code: DY1 4NG, Rating: None
# Care Home: Camelot Rest Home, Postal Code: DY1 2ER, Rating: None
# Care Home: Holly Lodge, Postal Code: DY8 2HA, Rating: None
# Care Home: Richmond Court Residential Home, Postal Code: DY1 3JD, Rating: None
# Care Home: Broadway Halls Care Home, Postal Code: DY1 3EA, Rating: None
# Care Home: The Mount Residential Home, Postal Code: DY8 4BQ, Rating: None
# Care Home: Ashgrove Nursing Home, Postal Code: DY2 0DA, Rating: None
# Care Home: Hollycroft Nursing Home, Postal Code: DY8 1ND, Rating: None
# Care Home: The Keepings, Postal Code: DY1 4AD, Rating: None
# Care Home: Swan Village Care Services - 44 Sedgley Road, Postal Code: DY1 4NG, Rating: None
# Care Home: Swan Village Care Services - 46 Sedgley Road, Postal Code: DY1 4NG, Rating: None
# Care Home: Abbeymere Care Centre, Postal Code: DY8 4QJ, Rating: None
# Care Home: Abbeygate Care Centre, Postal Code: DY5 3UR, Rating: None

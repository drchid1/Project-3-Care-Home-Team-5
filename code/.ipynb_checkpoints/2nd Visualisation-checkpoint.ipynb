# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# Load the CSV file into a DataFrame
file_path = "C:/Users/reach/Downloads/final_NH_data.xlsx"
df = pd.read_excel(file_path)

# Check the first few rows to understand the structure of the data
df.head()
# Out:
#                     Name                                            Address  \
# 0  Abbeygate Care Centre        2 Leys Road Brockmoor Brierley Hill DY5 3UR
# 1              Abbeymere    12 Eggington Road Wollaston Stourbridge DY8 2QJ
# 2     Amberley Care Home   481-483 Stourbridge Road Harts Hill Brierley ...
# 3     Ashbourne Care Ltd                      Lightwood Road Dudley DY1 2RS
# 4  Ashgrove Nursing Home        9 Dudley Wood Road Netherton Dudley DY2 0DA
#
#                                      Email  Telephone No Age Range  \
# 0                 abbeygatecare1@gmail.com  01384 571295       65+
# 1                 abbeymere@karelink.co.uk  01384 395195       65+
# 2  amberleycarehome@hotmail_x000D_\n.co.uk  01384 482365       65+
# 3                   ashbourne.m@fshc.co.uk  01384 242200       65+
# 4                     cea@ashgrovecare.com  01384 413913       65+
#
#                                   CQC Registered For Provide Nursing  \
# 0  Dementia _x000D_\nMental Health Condition _x00...              No
# 1  Dementia _x000D_\nMental Health Condition _x00...              No
# 2                          Dementia _x000D_\nOld Age              No
# 3                          Dementia _x000D_\nOld Age              No
# 4  Dementia _x000D_\nOld Age _x000D_\nSensory Imp...             Yes
#
#    Capacity Post Code       Care Home Name               Coordinates  \
# 0        17   DY5 3UR      Abbeygate Care   [52.4857514, -2.1341733]
# 1        18   DY8 2QJ           Abbeymere        [52.4584, -2.16295]
# 2        25   DY5 1LB  Amberley Care Home   [52.4927718, -2.1164204]
# 3        38   DY1 2RS  Ashbourne Care Ltd     [52.517467, -2.101861]
# 4        57   DY2 0DA    Ashgrove Nursing   [52.4777428, -2.0859231]
#
#     Latitude  Longitude               Rating
# 0  52.485751  -2.134173  No published rating
# 1  52.458400  -2.162950  No published rating
# 2  52.492772  -2.116420  No published rating
# 3  52.517467  -2.101861  No published rating
# 4  52.477743  -2.085923  No published rating

# %%
plt.figure(figsize=(10, 6))
plt.hist(df['Capacity'], bins=30, edgecolor='black')  # Set edgecolor to 'black' or any color you prefer
plt.title('Distribution of Care Home Capacities')
plt.xlabel('Capacity')
plt.ylabel('Count of Care Homes')

plt.show()

# %%
# Calculate the counts of each age range
age_range_counts = df['Age Range'].value_counts()

# Plot the bar chart
plt.figure(figsize=(10, 6))
plt.bar(age_range_counts.index, age_range_counts.values)
plt.title('Distribution of Age Ranges in Care Homes')
plt.xlabel('Age Range')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
# Plot 3: Ratings Distribution with different colors for each bar
rating_counts = df['Rating'].value_counts()
colors = ['skyblue', 'salmon', 'lightgreen', 'gold', 'orange']  # specify colors for each rating

plt.figure(figsize=(10, 6))
plt.bar(rating_counts.index, rating_counts.values, color=colors[:len(rating_counts)])
plt.title('Distribution of Care Home Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.show()

# %%
import matplotlib.pyplot as plt

# Sample data
nursing_counts = df['Provide Nursing'].value_counts()

# Define the explode offset for each slice
explode = [0.1] * len(nursing_counts)

# Define four different colors
colors = ['#66b3ff', '#ff9999', '#99ff99', '#ffcc99']

# Create a pie chart
plt.figure(figsize=(10, 6))
wedges, texts, autotexts = plt.pie(nursing_counts, labels=None, startangle=90, autopct='', explode=explode, colors=colors)



# Create a custom legend outside the pie chart with autopct
plt.legend(wedges, [f'{category}: {count} ({angle:.1f}%)' for category, count, angle in zip(nursing_counts.index, nursing_counts, [(count / sum(nursing_counts)) * 100 for count in nursing_counts])], title="Categories", loc="center left", bbox_to_anchor=(1, 0, 0.5, 1))

# Equal aspect ratio ensures that pie is drawn as a circle
plt.axis('equal')

plt.title('Proportion of Care Homes Providing Nursing Care')
plt.show()
